# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import numpy as np
import pandas as pd
data = pd.read_csv(r"\Users\HP\Desktop\Iris.csv")
# Out:
# C:\Users\HP\anaconda3\envs\pandas\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 0.9210526315789473

# %%
data.head(20)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa

# %%
features = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
x = data[features]
y = data['Species']

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(x,y)

# %%
print("Train Set:")
print(train_x)

# Print the test set records
print("\nTest Set:")
print(test_x)
# Out:
# Train Set:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 76             6.8           2.8            4.8           1.4
# 83             6.0           2.7            5.1           1.6
# 111            6.4           2.7            5.3           1.9
# 56             6.3           3.3            4.7           1.6
# 113            5.7           2.5            5.0           2.0
# ..             ...           ...            ...           ...
# 44             5.1           3.8            1.9           0.4
# 20             5.4           3.4            1.7           0.2
# 74             6.4           2.9            4.3           1.3
# 108            6.7           2.5            5.8           1.8
# 11             4.8           3.4            1.6           0.2
#
# [112 rows x 4 columns]
#
# Test Set:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 42             4.4           3.2            1.3           0.2
# 46             5.1           3.8            1.6           0.2
# 90             5.5           2.6            4.4           1.2
# 100            6.3           3.3            6.0           2.5
# 58             6.6           2.9            4.6           1.3
# 106            4.9           2.5            4.5           1.7
# 86             6.7           3.1            4.7           1.5
# 96             5.7           2.9            4.2           1.3
# 131            7.9           3.8            6.4           2.0
# 144            6.7           3.3            5.7           2.5
# 118            7.7           2.6            6.9           2.3
# 119            6.0           2.2            5.0           1.5
# 2              4.7           3.2            1.3           0.2
# 101            5.8           2.7            5.1           1.9
# 114            5.8           2.8            5.1           2.4
# 143            6.8           3.2            5.9           2.3
# 109            7.2           3.6            6.1           2.5
# 24             4.8           3.4            1.9           0.2
# 107            7.3           2.9            6.3           1.8
# 39             5.1           3.4            1.5           0.2
# 110            6.5           3.2            5.1           2.0
# 62             6.0           2.2            4.0           1.0
# 55             5.7           2.8            4.5           1.3
# 140            6.7           3.1            5.6           2.4
# 14             5.8           4.0            1.2           0.2
# 72             6.3           2.5            4.9           1.5
# 34             4.9           3.1            1.5           0.1
# 75             6.6           3.0            4.4           1.4
# 116            6.5           3.0            5.5           1.8
# 57             4.9           2.4            3.3           1.0
# 19             5.1           3.8            1.5           0.3
# 35             5.0           3.2            1.2           0.2
# 97             6.2           2.9            4.3           1.3
# 45             4.8           3.0            1.4           0.3
# 65             6.7           3.1            4.4           1.4
# 28             5.2           3.4            1.4           0.2
# 146            6.3           2.5            5.0           1.9
# 84             5.4           3.0            4.5           1.5

# %%
print("Train Set:")
print(train_y)

# Print the test set records
print("\nTest Set:")
print(test_y)
# Out:
# Train Set:
# 76     Iris-versicolor
# 83     Iris-versicolor
# 111     Iris-virginica
# 56     Iris-versicolor
# 113     Iris-virginica
#             ...
# 44         Iris-setosa
# 20         Iris-setosa
# 74     Iris-versicolor
# 108     Iris-virginica
# 11         Iris-setosa
# Name: Species, Length: 112, dtype: object
#
# Test Set:
# 42         Iris-setosa
# 46         Iris-setosa
# 90     Iris-versicolor
# 100     Iris-virginica
# 58     Iris-versicolor
# 106     Iris-virginica
# 86     Iris-versicolor
# 96     Iris-versicolor
# 131     Iris-virginica
# 144     Iris-virginica
# 118     Iris-virginica
# 119     Iris-virginica
# 2          Iris-setosa
# 101     Iris-virginica
# 114     Iris-virginica
# 143     Iris-virginica
# 109     Iris-virginica
# 24         Iris-setosa
# 107     Iris-virginica
# 39         Iris-setosa
# 110     Iris-virginica
# 62     Iris-versicolor
# 55     Iris-versicolor
# 140     Iris-virginica
# 14         Iris-setosa
# 72     Iris-versicolor
# 34         Iris-setosa
# 75     Iris-versicolor
# 116     Iris-virginica
# 57     Iris-versicolor
# 19         Iris-setosa
# 35         Iris-setosa
# 97     Iris-versicolor
# 45         Iris-setosa
# 65     Iris-versicolor
# 28         Iris-setosa
# 146     Iris-virginica
# 84     Iris-versicolor
# Name: Species, dtype: object

# %%
from sklearn.svm import SVC

model = SVC()
model.fit(train_x,train_y)
model.predict([[5.1,3.5,1.4,0.2]])

prediction = model.predict(test_x)
# Out:
# C:\Users\HP\anaconda3\envs\pandas\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_y, prediction)
# Out:
# 0.9736842105263158
